# %% [markdown]
# #Real Estate Property Analysis assignment question and answer

# %% [markdown]
# #Task 1: Analyze the Price Distribution of Properties Across Different Cities.Goal: Create a Horizontal bar to visualize property price variation in different cities.
#
# The dataset includes property listings with relevant details such as:
#
# - **City** (e.g., Mumbai, Delhi)
# - **Price (₹ Lakhs)** – price of the property
# - **Property Type**, **BHK**, **Area**, etc.
#
# To analyze the price distribution across different cities and create a **horizontal bar chart**, we’ll compute the **average price** of properties per city and visualize it. Let’s proceed.
#
# ![image.png](data:image/png;base64,...)
#
# Here's the horizontal bar chart showing the **average property price** across different cities:
#
# - Cities like **Delhi** and **Hyderabad** appear to have **higher average prices**.
# - Others like **Chennai** and **Kolkata** show **lower average prices**.

# %% [markdown]
# #Task 2: Compare Average Price for Each Property Type Goal: Create a Stacked Bar Chart showing the average price of different property types.
#
# We now have the **average price per property type** for each city. Next, let's visualize this data using a **stacked bar chart**, with cities on the x-axis and average prices for each property type stacked.
#
# ![image.png](data:image/png;base64,...)
#
# Here's the **stacked bar chart** showing the **average property price by type** in each city:
#
# - You can easily compare how much different property types (Apartment, Independent House, Villa) cost on average in each city.
# - Some cities, like **Chandigarh** and **Delhi**, show a wide range across property types.

# %% [markdown]
# #Task 3: Identify the Top 3 Most Expensive Properties Goal: Find the three highest-priced properties.
#
# Here are the **Top 3 Most Expensive Properties** in the dataset:
#
# 1. **Mumbai** – ₹280 Lakhs
#    - **Villa**, 5BHK, 3300 Sq. Ft, Seller: Builder, Status: Sold
#
# 2. **Chandigarh** – ₹275 Lakhs
#    - **Villa**, 5BHK, 3200 Sq. Ft, Seller: Owner, Status: Available
#
# 3. **Delhi** – ₹250 Lakhs
#    - **Villa**, 4BHK, 2500 Sq. Ft, Seller: Owner, Status: Sold
#
# All three are **villas**, emphasizing the premium pricing of that property type.

# %% [markdown]
# #Task 4: Show the Percentage of Properties Sold vs. Available Goal: Use a Pie Chart to compare Sold, Available, and Under Construction properties.
#
# ![image.png](data:image/png;base64,...)
#
# Here's the **pie chart** showing the percentage of properties by status:
#
# - You can clearly see the proportion of properties that are **Available**, **Sold**, or **Under Construction**.
# - This helps understand market activity and availability at a glance.

# %% [markdown]
# #Task 5: Price Per Sq. Ft Analysis by City Goal: Calculate the average price per square foot for each city to compare real estate value Visualization: Bar Chart showing average price per sq. ft. by city.
#
# ![image.png](data:image/png;base64,...)
#
# Here's the **bar chart** showing the **average price per square foot** for each city:
#
# - Cities like **Mumbai** and **Delhi** have the **highest price per sq. ft**, reflecting their premium real estate markets.
# - More affordable cities appear on the left with significantly lower average rates.

# %% [markdown]
# #Task 6: Group Properties by Price Range and Analyze Count Goal: Categorize properties into Low, Medium, and High price ranges and analyze how many fall into each. Visualization : Bar Chart showing how properties are distributed across different price bands.
#
# ![image.png](data:image/png;base64,...)
#
# Here's the **bar chart** showing how properties are distributed across **Low**, **Medium**, and **High** price ranges:
#
# - The **Medium** range (₹75–150 Lakhs) contains the **most properties**, indicating it's the most common price band.
# - **High-end** properties are fewer in number, and **Low-priced** ones also have a notable share.
